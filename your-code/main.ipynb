# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt 
from math import e 
from sqlalchemy import create_engine
import pandas as pd 
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.figure(figsize=(17,6))
plt.plot(x,y,c='rebeccapurple',label='square',lw=3)
plt.plot(x,z,c='red', label='cube',lw=3)
plt.legend()
plt.show()
plt.clf()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
f,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,10))
ax1.plot(x,y,c='rebeccapurple', label='square', lw=3)
ax2.plot(x,z,c='red', label='cube', lw=3)
f.legend(loc='center right')
plt.show()
plt.clf()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
f,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,6))
ax1.plot(x,y,c='rebeccapurple', label='square', lw=3)
ax2.plot(x,z,c='deepskyblue', label='cube', lw=3)
ax1.set_title('square')
ax2.set_title('cube')
f.subplots_adjust(bottom=0.2)
f.legend(loc='upper right')
f.suptitle("big title")
plt.show()
plt.clf()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y = x**2
z = e**x
f,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,6))
ax1.plot(x,y,c='rebeccapurple', label='square', lw=3)
ax2.plot(x,z,c='deepskyblue', label='cube', lw=3)
ax1.set_title('y=x^2')
ax2.set_title('y=e^x')
ax2.set_yscale('log')
ax1.set_yscale('linear')
f.subplots_adjust(bottom=0.2)
#f.legend(loc='upper right')
f.suptitle("big title")
plt.show()
plt.clf()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'fitbit'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/fitbit

# %%
engine = create_engine(connection_string)
print(engine)
# Out:
# Engine(mysql+pymysql://data-students:***@34.65.10.136/fitbit)

# %%
fitbit = pd.read_sql('SELECT * FROM fitbit2;', engine)
fitbit.shape
# Out:
# (367, 24)

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps Distance  Floors Minutes Sedentary  \
# 0  2015-05-08            1934    905     0.65       0             1.355
# 1  2015-05-09            3631  18925    14.11       4               611
# 2  2015-05-10            3204  14228    10.57       1               602
# 3  2015-05-11            2673   6756     5.02       8               749
# 4  2015-05-12            2495    502     3.73       1               876
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
for i in fitbit.columns:
    print(i)
# Out:
# Date
# Calorie burned
# Steps
# Distance
# Floors
# Minutes Sedentary
# Minutes Lightly Active
# Minutes Fairly Active
# Minutes Very Active
# Activity Calories
# MinutesOfSleep
# MinutesOfBeingAwake
# NumberOfAwakings
# LengthOfRestInMinutes
# Distance_miles
# Days
# Days_encoded
# Work_or_Weekend
# Hours Sleep
# Sleep efficiency
# Yesterday_sleep
# Yesterday_sleep_efficiency
# Months
# Months_encoded

# %%
fitbit.dtypes
# Out:
# Date                          object
# Calorie burned                 int64
# Steps                          int64
# Distance                      object
# Floors                         int64
# Minutes Sedentary             object
# Minutes Lightly Active         int64
# Minutes Fairly Active          int64
# Minutes Very Active            int64
# Activity Calories              int64
# MinutesOfSleep                 int64
# MinutesOfBeingAwake            int64
# NumberOfAwakings               int64
# LengthOfRestInMinutes          int64
# Distance_miles                object
# Days                          object
# Days_encoded                   int64
# Work_or_Weekend                int64
# Hours Sleep                   object
# Sleep efficiency              object
# Yesterday_sleep               object
# Yesterday_sleep_efficiency    object
# Months                        object
# Months_encoded                 int64
# dtype: object

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
months = fitbit.groupby("Months_encoded")["Steps"].median()
work = fitbit.groupby("Work_or_Weekend")["Steps"].median()

# %%
f,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
plt.sca(ax1)
months.plot(kind="bar")
plt.title("Months Vs. Steps")
plt.sca(ax2)
work.plot(kind="bar")
plt.title("Workdays/Weekends Vs. Steps")
plt.xticks(range(2), ['Work','WE'])
plt.show()
f.savefig('steps.png', dpi = 400, quality=100)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig, ax = plt.subplots(3,1,figsize=(17,18))
features = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for i,j in zip(features,ax):
    j.scatter(fitbit[i],fitbit['Steps'], s=50, color='blue', edgecolor='black', marker='*')
    j.set_xlabel(i)
    j.set_ylabel('Steps')
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'titanic'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)
engine = create_engine(connection_string)
print(engine)
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/titanic
# Engine(mysql+pymysql://data-students:***@34.65.10.136/titanic)

# %%
titanic = pd.read_sql('SELECT * FROM titanic;', engine)
titanic.shape
# Out:
# (1309, 12)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['float64','int64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
#añdlskf

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
